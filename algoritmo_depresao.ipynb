# %%
from time import sleep

nome = input('Olá, usuário! Informe o seu nome: ')

sleep(3)

print(f'Ok, {nome}! Escolha as opções abaixo de acordo com a frequência de cada resposta, ok?')

sleep(3)

print('''
As opções de resposta vão de 1 a 5, sendo:
1- Discordo totalmente
2- Discordo em partes
3- Concordo um pouco
4- Concordo bastante
5- Concordo plenamente
''')

sleep(3)

print(f'Serão 12 tópicos ok, {nome}? Responda o quanto você concorda!')

sleep (3)

pergunta1 = int(input('1)Você tem vivido por tempo prolongado episódios de sono excessivo ou insônia [1-5]: '))
while pergunta1 < 1 or pergunta1 > 5:
  pergunta1 = int(input('Opção incorreta, tente um número de 1 a 5: '))

pergunta2 = int(input('2)Você tem sentido falta de energia para realizar suas atividades diárias [1-5]: '))
while pergunta2 < 1 or pergunta2 > 5:
  pergunta2 = int(input('Opção incorreta, tente um número de 1 a 5: '))

pergunta3 = int(input('3)Você tem passado por alterações de apetite como muita ou pouca fome [1-5]: '))
while pergunta3 < 1 or pergunta3 > 5:
  pergunta3 = int(input('Opção incorreta, tente um número de 1 a 5: '))

pergunta4 = int(input('4)Perdeu o interesse em atividades que antes eram prazerosas [1-5]: '))
while pergunta4 < 1 or pergunta4 > 5:
  pergunta4 = int(input('Opção incorreta, tente um número de 1 a 5: '))

pergunta5 = int(input('5)Sente constantemente sentimentos como irritabilidade, pessimismo, tristeza, angústia, desânimo ou medo [1-5]: '))
while pergunta5 < 1 or pergunta5 > 5:
  pergunta5 = int(input('Opção incorreta, tente um número de 1 a 5: '))

pergunta6 = int(input('6)Sente dificuldades em manter relações pessoais e socializar [1-5]: '))
while pergunta6 < 1 or pergunta6 > 5:
  pergunta6 = int(input('Opção incorreta, tente um número de 1 a 5: '))

pergunta7 = int(input('7)Não pratica nenhuma atividade física [1-5]: '))
while pergunta7 < 1 or pergunta7 > 5:
  pergunta7 = int(input('Opção incorreta, tente um número de 1 a 5: '))

pergunta8 = int(input('8)Não possui uma alimentação saudável [1-5]: '))
while pergunta8 < 1 or pergunta8 > 5:
  pergunta8 = int(input('Opção incorreta, tente um número de 1 a 5: '))

pergunta9 = int(input('9)Possui algum histórico de vício [1-5]: '))
while pergunta9 < 1 or pergunta9 > 5:
  pergunta9 = int(input('Opção incorreta, tente um número de 1 a 5: '))

pergunta10 = int(input('10)Possui algum histórico familiar de depressão [1-5] '))
while pergunta10 < 1 or pergunta10 > 5:
  pergunta10 = int(input('Opção incorreta, tente um número de 1 a 5: '))

pergunta11 = int(input('11)Passou ou tem passado por traumas físicos ou psicológicos [1-5] '))
while pergunta11 < 1 or pergunta11 > 5:
  pergunta11 = int(input('Opção incorreta, tente um número de 1 a 5: '))

pergunta12 = int(input('12)Tem dificuldades para se concentrar [1-5] '))
while pergunta12 < 1 or pergunta12 > 5:
  pergunta12 = int(input('Opção incorreta, tente um número de 1 a 5: '))

soma = pergunta1 + pergunta2 + pergunta3 +pergunta4 + pergunta5 + pergunta6 + pergunta7 + pergunta8 + pergunta9 + pergunta10 + pergunta11 + pergunta12

print(f'Você fez {soma} pontos, {nome}!')

if soma <20:
  print('\033[32mZona segura:\033[0m Você parece estar em uma zona segura, mas sempre fique atento!')
if soma > 20 and soma < 36:
  print('\033[35mZona de atenção:\033[0m Você não está na pontuação ideal, mas talvez algumas mudanças de hábito possam reverter a situação. Fique atento caso haja piora! ')
if soma > 36 and soma <45:
  print('\033[33mZona de cuidado:\033[0m É importante ficar alerta e buscar algum acompanhamento e mudanças de hábitos para evitar que evolua para um quadro grave de depressão. ')
if soma >45:
  print('\033[91mZona de perigo:\033[0m Cuidado! É importante buscar ajuda profissional. ')
